# %% [markdown]
# Name : Ng Chen Ting
# # Part B
# ## Task 1. Processing Data Stream
# ### Event Producer 3

# %%
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import pandas
import csv
import random
import datetime as dt

hostip = "192.168.1.14" 

def load_data_from_csv():
    """
    Load data from 'hotspot_TERRA_streaming.csv' and format it into a list of dictionaries.
    """
    terra_streaming_data = pandas.read_csv('hotspot_TERRA_streaming.csv') 
    data = []
    
    # Iterate through each row 
    for _, row in terra_streaming_data.iterrows(): 
        data_row = {} 
        data_row['latitude'] = float(row['latitude'])
        data_row['longitude'] = float(row['longitude'])
        data_row['confidence'] = int(row['confidence'])
        data_row['surface_temperature_celcius'] = int(row['surface_temperature_celcius'])
        data.append(data_row)
    return data


def publish_message(producer_instance, topic_name, value):
    try:
        # To convert them to bytes 
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, value=value_bytes)

        # To ensure the message is actually sent to Kafka 
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(value))
        
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
        
    finally:
        return _producer
    
    
if __name__ == '__main__':
    topic = 'Assignment_TaskB_Hotspots'
    print('Publishing records..')
    producer = connect_kafka_producer()
    data = load_data_from_csv()
    
    while True:
        try:
            # Get a random line from 'hotspot_TERRA_streaming.csv'
            random_line = random.choice(data)

            # Add producer_id to indicate it's from TERRA producer
            random_line['producer_id'] = 'producer_hotspot_terra'  
            
            # Generate a random time
            random_time = dt.time(hour=random.randint(0, 23), minute=random.randint(0, 59), second=random.randint(0, 59))
            random_line['created_time'] = random_time.strftime("%H:%M:%S")  

            # Convert the dictionary to a JSON string and publish
            json_data = dumps(random_line) 
            publish_message(producer, topic, json_data) 
            sleep(random.randint(3,7))      # Wait a random time between 1 to 7 seconds

        except KeyboardInterrupt:
            print('Exiting...')
            break
# Out:
# Publishing records..
# Message published successfully. Data: {"latitude": -36.174, "longitude": 142.737, "confidence": 79, "surface_temperature_celcius": 52, "producer_id": "producer_hotspot_terra", "created_time": "06:47:39"}
# Message published successfully. Data: {"latitude": -37.7509, "longitude": 143.4023, "confidence": 98, "surface_temperature_celcius": 82, "producer_id": "producer_hotspot_terra", "created_time": "02:06:40"}
# Message published successfully. Data: {"latitude": -37.465, "longitude": 148.153, "confidence": 68, "surface_temperature_celcius": 63, "producer_id": "producer_hotspot_terra", "created_time": "12:19:16"}
# Message published successfully. Data: {"latitude": -36.8573, "longitude": 143.5278, "confidence": 69, "surface_temperature_celcius": 45, "producer_id": "producer_hotspot_terra", "created_time": "13:02:37"}
# Message published successfully. Data: {"latitude": -36.3182, "longitude": 141.6684, "confidence": 64, "surface_temperature_celcius": 42, "producer_id": "producer_hotspot_terra", "created_time": "08:23:02"}
# Message published successfully. Data: {"latitude": -36.8834, "longitude": 142.2701, "confidence": 76, "surface_temperature_celcius": 50, "producer_id": "producer_hotspot_terra", "created_time": "03:42:51"}
# Message published successfully. Data: {"latitude": -36.3739, "longitude": 141.3614, "confidence": 85, "surface_temperature_celcius": 59, "producer_id": "producer_hotspot_terra", "created_time": "21:42:32"}
# Message published successfully. Data: {"latitude": -37.624, "longitude": 149.314, "confidence": 90, "surface_temperature_celcius": 66, "producer_id": "producer_hotspot_terra", "created_time": "00:07:26"}
# Message published successfully. Data: {"latitude": -37.9164, "longitude": 143.4866, "confidence": 58, "surface_temperature_celcius": 54, "producer_id": "producer_hotspot_terra", "created_time": "20:03:26"}
# Message published successfully. Data: {"latitude": -37.461, "longitude": 148.105, "confidence": 76, "surface_temperature_celcius": 42, "producer_id": "producer_hotspot_terra", "created_time": "00:39:13"}
# Message published successfully. Data: {"latitude": -38.16, "longitude": 143.803, "confidence": 62, "surface_temperature_celcius": 41, "producer_id": "producer_hotspot_terra", "created_time": "14:52:19"}
# Message published successfully. Data: {"latitude": -38.0781, "longitude": 143.9374, "confidence": 80, "surface_temperature_celcius": 54, "producer_id": "producer_hotspot_terra", "created_time": "02:47:02"}
# Message published successfully. Data: {"latitude": -37.067, "longitude": 141.379, "confidence": 69, "surface_temperature_celcius": 36, "producer_id": "producer_hotspot_terra", "created_time": "18:02:45"}
# Message published successfully. Data: {"latitude": -36.6664, "longitude": 144.7828, "confidence": 82, "surface_temperature_celcius": 55, "producer_id": "producer_hotspot_terra", "created_time": "06:59:11"}
# Message published successfully. Data: {"latitude": -36.0189, "longitude": 145.6844, "confidence": 75, "surface_temperature_celcius": 49, "producer_id": "producer_hotspot_terra", "created_time": "18:38:39"}
# Message published successfully. Data: {"latitude": -38.1756, "longitude": 143.9829, "confidence": 65, "surface_temperature_celcius": 53, "producer_id": "producer_hotspot_terra", "created_time": "14:01:16"}
# Message published successfully. Data: {"latitude": -37.1262, "longitude": 141.7213, "confidence": 88, "surface_temperature_celcius": 63, "producer_id": "producer_hotspot_terra", "created_time": "12:29:23"}
# Message published successfully. Data: {"latitude": -36.0157, "longitude": 145.9414, "confidence": 92, "surface_temperature_celcius": 70, "producer_id": "producer_hotspot_terra", "created_time": "20:37:31"}
# Message published successfully. Data: {"latitude": -37.1815, "longitude": 146.7777, "confidence": 71, "surface_temperature_celcius": 46, "producer_id": "producer_hotspot_terra", "created_time": "05:16:48"}
# Message published successfully. Data: {"latitude": -36.9442, "longitude": 142.9619, "confidence": 86, "surface_temperature_celcius": 61, "producer_id": "producer_hotspot_terra", "created_time": "11:44:12"}
# Message published successfully. Data: {"latitude": -37.7037, "longitude": 142.3299, "confidence": 62, "surface_temperature_celcius": 41, "producer_id": "producer_hotspot_terra", "created_time": "00:28:28"}
# Message published successfully. Data: {"latitude": -38.0674, "longitude": 142.965, "confidence": 91, "surface_temperature_celcius": 68, "producer_id": "producer_hotspot_terra", "created_time": "05:18:13"}
# Message published successfully. Data: {"latitude": -35.962, "longitude": 143.791, "confidence": 76, "surface_temperature_celcius": 42, "producer_id": "producer_hotspot_terra", "created_time": "11:56:41"}
